# %%
print("test branching")
# Out:
# test branching

# %%
print("hi beautiful")
# Out:
# hi beautiful

# %%
print("another one bites the branch")
# Out:
# another one bites the branch

# %%
for i in range(2):
    print("hi")
# Out:
# hi
# hi

# %%
print("in teams we say branch. alone we say bush.")
# Out:
# in teams we say branch. alone we say bush.

# %%
for i in range(3):
    print("Nora is so cool.")
# Out:
# Nora is so cool.
# Nora is so cool.
# Nora is so cool.

# %%
print("pls virk tak")
# Out:
# pls virk tak

# %%
print("det vil aldrig virke")
# Out:
# det vil aldrig virke

# %%
print("og næste gang så tage vi ham...")
# Out:
# og næste gang så tage vi ham...

# %%
print("...og putter ham i gryden.")
# Out:
# ...og putter ham i gryden.
